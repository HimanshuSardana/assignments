# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # EDA

# %%
df = pd.read_csv("./train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 102 entries, id to target
# dtypes: float64(100), int64(2)
# memory usage: 7.8 MB

# %%
df.describe()
# Out:
#                 id            f1            f2            f3            f4  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      0.155026      0.053651      0.036846      0.012196
# std     2886.89568      6.410881      2.758584      2.755553      7.109236
# min        1.00000    -29.460000    -11.890000    -10.410000    -35.690000
# 25%     2500.75000     -4.062500     -1.810000     -1.820000     -4.610000
# 50%     5000.50000      0.090000     -0.010000      0.050000      0.010000
# 75%     7500.25000      4.340000      1.910000      1.850000      4.550000
# max    10000.00000     28.950000     10.790000      9.860000     28.820000
#
#                  f5            f6            f7            f8            f9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.007097      0.155026      0.036586     -0.002948      0.004240
# std        2.777898      6.410881      7.924615      2.810345      0.999807
# min      -10.850000    -29.460000    -26.970000    -11.530000     -3.860000
# 25%       -1.850000     -4.062500     -5.230000     -1.880000     -0.670000
# 50%       -0.020000      0.090000      0.000000      0.010000      0.000000
# 75%        1.830000      4.340000      5.140000      1.872500      0.670000
# max       10.600000     28.950000     33.860000     10.730000      4.020000
#
#        ...           f92           f93           f94           f95  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...     -0.036761     -0.029496      0.080993      0.000539
# std    ...      2.803655      2.800850      2.761299      1.003666
# min    ...    -10.250000    -11.600000    -10.620000     -3.520000
# 25%    ...     -1.920000     -1.930000     -1.710000     -0.680000
# 50%    ...     -0.030000     -0.020000      0.110000     -0.010000
# 75%    ...      1.870000      1.860000      1.910000      0.682500
# max    ...     10.990000      9.850000     10.460000      3.820000
#
#                 f96           f97           f98           f99          f100  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.025507     -0.032087     -0.032087      0.053651      0.012196
# std        7.733279      2.753372      2.753372      2.758584      7.109236
# min      -29.000000    -12.160000    -12.160000    -11.890000    -35.690000
# 25%       -5.220000     -1.880000     -1.880000     -1.810000     -4.610000
# 50%        0.000000     -0.010000     -0.010000     -0.010000      0.010000
# 75%        5.112500      1.780000      1.780000      1.910000      4.550000
# max       31.040000     10.570000     10.570000     10.790000     28.820000
#
#              target
# count  10000.000000
# mean       9.459800
# std        5.781378
# min        0.000000
# 25%        4.000000
# 50%        9.000000
# 75%       15.000000
# max       19.000000
#
# [8 rows x 102 columns]

# %% [markdown]
# A few columns are duplicated, We must remove these

# %%
duplicates = df.T.duplicated()
df = df.loc[:, ~duplicates]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int64
#  1   f1      10000 non-null  float64
#  2   f2      10000 non-null  float64
#  3   f3      10000 non-null  float64
#  4   f4      10000 non-null  float64
#  5   f5      10000 non-null  float64
#  6   f7      10000 non-null  float64
#  7   f8      10000 non-null  float64
#  8   f9      10000 non-null  float64
#  9   f10     10000 non-null  float64
#  10  f11     10000 non-null  float64
#  11  f12     10000 non-null  float64
#  12  f13     10000 non-null  float64
#  13  f14     10000 non-null  float64
#  14  f15     10000 non-null  float64
#  15  f16     10000 non-null  float64
#  16  f17     10000 non-null  float64
#  17  f19     10000 non-null  float64
#  18  f21     10000 non-null  float64
#  19  f22     10000 non-null  float64
#  20  f24     10000 non-null  float64
#  21  f25     10000 non-null  float64
#  22  f26     10000 non-null  float64
#  23  f30     10000 non-null  float64
#  24  f31     10000 non-null  float64
#  25  f34     10000 non-null  float64
#  26  f35     10000 non-null  float64
#  27  f36     10000 non-null  float64
#  28  f38     10000 non-null  float64
#  29  f40     10000 non-null  float64
#  30  f41     10000 non-null  float64
#  31  f42     10000 non-null  float64
#  32  f44     10000 non-null  float64
#  33  f45     10000 non-null  float64
#  34  f49     10000 non-null  float64
#  35  f50     10000 non-null  float64
#  36  f54     10000 non-null  float64
#  37  f55     10000 non-null  float64
#  38  f57     10000 non-null  float64
#  39  f60     10000 non-null  float64
#  40  f62     10000 non-null  float64
#  41  f64     10000 non-null  float64
#  42  f65     10000 non-null  float64
#  43  f66     10000 non-null  float64
#  44  f76     10000 non-null  float64
#  45  f78     10000 non-null  float64
#  46  f80     10000 non-null  float64
#  47  f88     10000 non-null  float64
#  48  f89     10000 non-null  float64
#  49  f91     10000 non-null  float64
#  50  f95     10000 non-null  float64
#  51  target  10000 non-null  int64
# dtypes: float64(50), int64(2)
# memory usage: 4.0 MB

# %%
features = df.drop(columns=["id", "target"])

# %%
scaler = StandardScaler()
