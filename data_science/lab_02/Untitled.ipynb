# %% [markdown]
# Question 1: Install and configure `swirl` package for self learning.

# %%
install.packages("swirl", dependencies=TRUE)
install.packages("stringi")
install.packages("stringr")
# Out:
# Installing package into ‘/home/himanshu/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)

# %%
library(swirl)
# Out:
# | Hi! Type swirl() when you are ready to begin.
